# %%
G0I=np.genfromtxt('HD16901_G0I.dat')
G0V=np.genfromtxt('HD141004_G0V.dat')
G4Ia=np.genfromtxt('HD6474_G4Ia.dat')
G5V=np.genfromtxt('HD20630_G5V.dat')
K0V=np.genfromtxt('HD3651_K0V.dat')
K0Ib=np.genfromtxt('HD12014_K0Ib.dat')
x_G0I=G0I[:,0]
y_G0I=G0I[:,1]
x_G0V=G0V[:,0]
y_G0V=G0V[:,1]
x_G4Ia=G4Ia[:,0]
y_G4Ia=G4Ia[:,1]
x_G5V=G5V[:,0]
y_G5V=G5V[:,1]
x_K0V=K0V[:,0]
y_K0V=K0V[:,1]
x_K0Ib=K0Ib[:,0]
y_K0Ib=K0Ib[:,1]

# plt.plot(x_G0I,y_G0I, color='darkblue', lw=1, ls='-', label='G0I')
plt.plot(x_G0V,y_G0V, color='blue', lw=1, ls='-', label='G0V')
# plt.plot(x_G4Ia,y_G4Ia, color='lightblue', lw=1, ls='-', label='G4Ia')
plt.plot(x_G5V,y_G5V, color='salmon', lw=1, ls='-', label='G5V')
# plt.plot(x_K0V,y_K0V, color='red', lw=1, ls='-', label='K0V')
# plt.plot(x_K0Ib,y_K0Ib, color='red', lw=1, ls='-', label='K0Ib')
plt.xlabel('$\lambda$ ($\t{\AA}$)')
plt.ylabel("Normalized flux")
plt.xlim(3800, 5000)
plt.xticks(np.arange(3800,5000,100))
plt.xticks(np.arange(3800,5000,50), minor=True)
#plt.legend(loc="upper right")
plt.grid(False)
plt.show()
