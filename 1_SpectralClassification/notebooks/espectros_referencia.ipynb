# %% [markdown]
# Importing packages

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

os.getcwd()
# Out:
# 'c:\\Users\\Pablo\\OneDrive - Universidad de La Laguna\\Master\\Cuatri1\\AtmosferasEstelares\\CosasDuranteCurso\\Entregables\\_github\\1_SpectralClassification\\notebooks'

# %% [markdown]
# Saving the reference stars type

# %%
names_dir = os.listdir('../data/espectros_referencia')
names = [x.split('_')[1] for x in names_dir[:-1]]
names[0] = names_dir[0].split('_')[2]
names = [x.split('.')[0] for x in names]
names = sorted(names, key=str.lower)
print(names)
# Out:
# ['A0I', 'A0V', 'A5Ia', 'A5V', 'B0Ib', 'B0V', 'B5Ia', 'B5V', 'F0II', 'F0V', 'F5I', 'F5V', 'G0I', 'G0V', 'G4Ia', 'G5V', 'K0Ib', 'K0V', 'K4p5Ib', 'K5V', 'M0I', 'M0V', 'M4II', 'M4p5V', 'O4If', 'O4V', 'O7Ib(f)', 'O7V']

# %% [markdown]
# Extracting the data for each star

# %%
spectra_dir = '../data/espectros_referencia/'
B0V = np.genfromtxt(spectra_dir+names_dir[0])
M4p5V = np.genfromtxt(spectra_dir+names_dir[1])
K0Ib = np.genfromtxt(spectra_dir+names_dir[2])
B5Ia = np.genfromtxt(spectra_dir+names_dir[3])
M0I = np.genfromtxt(spectra_dir+names_dir[4])
G0V = np.genfromtxt(spectra_dir+names_dir[5])
B0Ib = np.genfromtxt(spectra_dir+names_dir[6])
G0I = np.genfromtxt(spectra_dir+names_dir[7])
A5Ia = np.genfromtxt(spectra_dir+names_dir[8])
M4II = np.genfromtxt(spectra_dir+names_dir[9])
O4If = np.genfromtxt(spectra_dir+names_dir[10])
K5V = np.genfromtxt(spectra_dir+names_dir[11])
G5V = np.genfromtxt(spectra_dir+names_dir[11])
F5I = np.genfromtxt(spectra_dir+names_dir[12])
K4p5Ib = np.genfromtxt(spectra_dir+names_dir[13])
A5V = np.genfromtxt(spectra_dir+names_dir[14])
F5V = np.genfromtxt(spectra_dir+names_dir[15])
A0V = np.genfromtxt(spectra_dir+names_dir[16])
B5V = np.genfromtxt(spectra_dir+names_dir[17])
K0V = np.genfromtxt(spectra_dir+names_dir[18])
F0II = np.genfromtxt(spectra_dir+names_dir[19])
O4V = np.genfromtxt(spectra_dir+names_dir[20])
G4Ia = np.genfromtxt(spectra_dir+names_dir[21])
O7Ib_f = np.genfromtxt(spectra_dir+names_dir[22])
M0V = np.genfromtxt(spectra_dir+names_dir[23])
A0I = np.genfromtxt(spectra_dir+names_dir[24])
F0V = np.genfromtxt(spectra_dir+names_dir[25])
O7V = np.genfromtxt(spectra_dir+names_dir[26])

# x_B0V = B0V[:, 0]
# y_B0V = B0V[:, 1]
# x_M4p5V = M4p5V[:, 0]
# y_M4p5V = M4p5V[:, 1]
# x_K0Ib = K0Ib[:, 0]
# y_K0Ib = K0Ib[:, 1]
# x_B5Ia = B5Ia[:, 0]
# y_B5Ia = B5Ia[:, 1]
# x_M0I = M0I[:, 0]
# y_M0I = M0I[:, 1]
# x_G0V = G0V[:, 0]
# y_G0V = G0V[:, 1]
# x_B0Ib = B0Ib[:, 0]
# y_B0Ib = B0Ib[:, 1]
# x_G0I = G0I[:, 0]
# y_G0I = G0I[:, 1]
# x_A5Ia = A5Ia[:, 0]
# y_A5Ia = A5Ia[:, 1]
# x_M4II = M4II[:, 0]
# y_M4II = M4II[:, 1]
# x_O4If = O4If[:, 0]
# y_O4If = O4If[:, 1]
# x_K5V = K5V[:, 0]
# y_K5V = K5V[:, 1]
# x_G5V = G5V[:, 0]
# y_G5V = G5V[:, 1]
# x_F5I = F5I[:, 0]
# y_F5I = F5I[:, 1]
# x_K4p5Ib = K4p5Ib[:, 0]
# y_K4p5Ib = K4p5Ib[:, 1]
# x_A5V = A5V[:, 0]
# y_A5V = A5V[:, 1]
# x_F5V = F5V[:, 0]
# y_F5V = F5V[:, 1]
# x_A0V = A0V[:, 0]
# y_A0V = A0V[:, 1]
# x_B5V = B5V[:, 0]
# y_B5V = B5V[:, 1]
# x_K0V = K0V[:, 0]
# y_K0V = K0V[:, 1]
# x_F0II = F0II[:, 0]
# y_F0II = F0II[:, 1]
# x_O4V = O4V[:, 0]
# y_O4V = O4V[:, 1]
# x_G4Ia = G4Ia[:, 0]
# y_G4Ia = G4Ia[:, 1]
# x_O7Ib_f = O7Ib_f[:, 0]
# y_O7Ib_f = O7Ib_f[:, 1]
# x_M0V = M0V[:, 0]
# y_M0V = M0V[:, 1]
# x_A0I = A0I[:, 0]
# y_A0I = A0I[:, 1]
# x_F0V = F0V[:, 0]
# y_F0V = F0V[:, 1]
# x_O7V = O7V[:, 0]
# y_O7V = O7V[:, 1]

df_x = [] #np.zeros([len(names), 1333])
df_y = [] #np.zeros([len(names), 1333])
for x in range(len(names)):
    if names[x] == 'O7Ib(f)':
        test_x = 'O7Ib_f'
        df_x.append(globals()[test_x][:, 0]) # np.append(df_x, globals()[test_x])
        df_y.append(globals()[test_x][:, 1]) # np.append(df_y, globals()[test_x])
    else:
        df_x.append(globals()[names[x]][:, 0])
        df_y.append(globals()[names[x]][:, 1])

# %% [markdown]
# Plotting all reference spectra

# %%
for x in range(len(names)):
    plt.title(names[x])
    plt.plot(df_x[x], df_y[x], c='k')
    plt.ylim(min(df_y[x])-0.1, 1.2)
    plt.xlabel(f'$\lambda$ ($\AA$)')
    plt.ylabel('Normalized flux')
    plt.tight_layout()
    # plt.savefig('../results/espectros_referencia/'+names[x])
    plt.show()
